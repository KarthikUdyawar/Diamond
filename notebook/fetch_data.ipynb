# %%
import opendatasets as od
import pandas as pd
import numpy as np

# %%
dataset_url = "https://www.kaggle.com/datasets/harshitlakhani/natural-diamonds-prices-images"
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Downloading natural-diamonds-prices-images.zip to ./natural-diamonds-prices-images
# 100%|██████████| 154M/154M [00:32<00:00, 4.93MB/s]
