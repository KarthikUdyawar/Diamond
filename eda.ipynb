# %%
print("Hello World")
# Out:
# Hello World

# %%
import opendatasets as od
import pandas as pd

# %%
dataset_url = "https://www.kaggle.com/datasets/shivam2503/diamonds"
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Downloading diamonds.zip to ./diamonds
# 100%|██████████| 733k/733k [00:00<00:00, 10.6MB/s]
